# %%
# %load_ext autoreload
# %autoreload 2

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
GRAPH_FILE = '../code/data/ng20/test_system/100/yes.graph'
g_mult_dir = nx.read_gml(GRAPH_FILE, label = 'name')

# %%
fig = plt.figure(figsize=(30, 30))
pos=nx.spring_layout(g_mult_dir)
nx.draw(g_mult_dir, pos = pos)

edge_labels=dict([((u,v,),d['name'])
             for u,v,d in g_mult_dir.edges(data=True)])
nx.draw_networkx_edge_labels(g_mult_dir,pos,edge_labels=edge_labels)
nx.draw_networkx_nodes(g_mult_dir, pos = pos, label='name', )
nx.draw_networkx_labels(g_mult_dir, pos = pos)
plt.show()
# Out:
# /Users/davidgengenbach/anaconda3/lib/python3.5/site-packages/networkx/drawing/nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   b = plt.ishold()
# /Users/davidgengenbach/anaconda3/lib/python3.5/site-packages/networkx/drawing/nx_pylab.py:138: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(b)
# /Users/davidgengenbach/anaconda3/lib/python3.5/site-packages/matplotlib/__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# ...

# %%
nx.draw_networkx?

# %%
for source, target, data in g_mult_dir.edges_iter(data = True):
    print(source, data['label'], target)
# Out:
# some people consider their interests more important than open scientific discussion
# how are block ciphers used to encrypt data longer than the block size
# how are block ciphers used to encrypt data longer than the block size
# a secret society serves the national secu
# notes such as ``[kah67 refer to the reference list in the last part
# sci.crypt has been archived on cl-next2
# sci.crypt has been archived since october 1991
# des to protect classified information
# the cryptography  faq is posted to news.answers
# the cryptography  faq is posted to sci.answers
# the cryptography  faq is posted to the newsgroups sci.crypt , sci.answers , and news.answers every 21 days
# the cryptography  faq is posted to the newsgroups sci.crypt
# this document is the product of the crypt cabal
# this faq is at all complete at this point
# these archives are available only to u.s. and canadian users
# many people have contributed to this faq
# what references to learn cryptology
# ...

# %%
import re
with open('../code/data/ng20/train/100/0.txt' ,  'r') as f:
    text = f.read()
reg = r'\n\n+'
print(re.sub('\n', ' ', re.sub(reg, '//', text)).replace('//', '\n\n'))
# Out:
# Archive-name: cryptography-faq/part01 Last-modified: 1993/4/15
#
# FAQ for sci.crypt, part 1: Overview
#
# This is the first of ten parts of the sci.crypt FAQ. The parts are mostly independent, but you should read this part before the rest. We don't have the time to send out missing parts by mail, so don't ask. Notes such as ``[KAH67]'' refer to the reference list in the last part.
#
# Disclaimer: This document is the product of the Crypt Cabal, a secret society which serves the National Secu---uh, no. Seriously, we're the good guys, and we've done what we can to ensure the completeness and accuracy of this document, but in a field of military and commercial importance like cryptography you have to expect that some people and organizations consider their interests more important than open scientific discussion. Trust only what you can verify firsthand. And don't sue us.
#
# ...
